# %%
# Imports
# %load_ext autoreload
# %autoreload 2

import json
from dwitracts.main import DwiTracts
import dwitracts.plot as plot
# Out:
# /gpfs01/home/lpxjr4/.conda/envs/dwi-tracts/lib/python3.7/site-packages/nilearn/__init__.py:67: FutureWarning: Python 3.7 support is deprecated and will be removed in release 0.12 of Nilearn. Consider switching to Python 3.9 or 3.10.
#   _python_deprecation_warnings()

# %%
# Initialize a DwiTract project
config_file = 'project/config_tracts_lc.json'


with open(config_file, 'r') as myfile:
    params = json.loads(myfile.read())

my_dwi = DwiTracts( params )

assert my_dwi.initialize()
# Out:
# Creating debug directory at /share/ConnLS/ADNI/tract_stats/LC-MTL/debug
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_LC_L_Ent_L.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_LC_L_LC_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_LC_L_Ent_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_LC_L_PirT_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_LC_L_PirTB_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_Ent_L_PirT_L.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_Ent_L_PirTB_L.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_Ent_L_LC_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_Ent_L_Ent_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_Ent_L_PirT_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_Ent_L_PirTB_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirT_L_PirTB_L.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirT_L_LC_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirT_L_Ent_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirT_L_PirT_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirT_L_PirTB_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirTB_L_LC_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirTB_L_Ent_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirTB_L_PirT_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirTB_L_PirTB_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_Ent_R_PirT_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_Ent_R_PirTB_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirT_R_PirTB_R.nii.gz

# %%
# Compute bidirectional average distributions for each tract ([AB + BA] / 2)

assert my_dwi.compute_bidirectional_averages( verbose=True, clobber=True, debug=True )

# %%
# Compute tract distances (A->B and B->A) for each tract

assert my_dwi.compute_tract_distances( verbose=True, clobber=True, debug=True )

# %%
# Generate core polylines, gaussian uncertainty fields, and unidirectional tract estimates 

assert my_dwi.estimate_unidirectional_tracts( verbose=True, clobber=True, debug=True )

# %%
# Generate bidirectional tract estimates 

assert my_dwi.estimate_bidirectional_tracts( verbose=True, clobber=True )

# %%
# Create a pass/fail Pajek graph

assert my_dwi.tracts_to_pajek( verbose=True, clobber=True )

# %%
# Compute voxel-wise average streamline orientations for each tract

assert my_dwi.compute_average_orientations( verbose=True, clobber=True )

# %%
# Compute tract-specific anisotropy

assert my_dwi.compute_tsa( verbose=True, clobber=True )

# %%
# Generate average TSA images for each tract

assert my_dwi.generate_mean_tsa_images( verbose=True )
# Out:
# Progress:   0%|          | 0/5 [00:00<?, ?it/s]
# Done tract LC_L_PirT_L
# Done tract LC_L_PirTB_L
# Done tract LC_R_Ent_R
# Done tract LC_R_PirT_R
# Done tract LC_R_PirTB_R
# Average TSA images saved to /share/ConnLS/ADNI/tract_stats/LC-MTL/tsa_avr

# %%
# Plot TSA histograms
params_plot = {}
params_plot['axis_font'] = 18
params_plot['ticklabel_font'] = 12
params_plot['title_font'] = 18
params_plot['show_labels'] = False
params_plot['show_title'] = False
params_plot['dimensions_tracts'] = (50,40)
params_plot['dimensions_all'] = (50,40)
params_plot['dpi_tracts'] = 150
params_plot['dpi_all'] = 300
params_plot['num_bins'] = 20
params_plot['kde'] = True
params_plot['stat'] = 'density'
params_plot['xlim'] = [-0.25, 0.75]
params_plot['xticks'] = [-0.25, 0.0, 0.25, 0.50, 0.75]
params_plot['color'] = '#2b3ad1'  # blue
params_plot['image_format'] = 'pdf'

tract_names = None

for threshold in [0.1,0.3,0.5]:
    stats = plot.plot_tsa_histograms( params_plot, my_dwi, tract_names=tract_names, threshold=threshold, \
                                      verbose=True, clobber=True )

    # Save TSA stats to CSV file
    stats.to_csv('{0}/stats_tsa_{1:02d}.csv'.format(my_dwi.tracts_dir, round(threshold*100)))
# Out:
# Threshold: 0.1
# Generating histograms:   0%|          | 0/4 [00:00<?, ?it/s]
#  Done tract LC_L_PirTB_L
#  Done tract LC_L_PirT_L
#  Done tract LC_R_PirTB_R
#  Done tract LC_R_PirT_R
#  Generated histograms in /share/ConnLS/ADNI/tract_stats/LC-MTL/figures.
# Threshold: 0.3
# Generating histograms:   0%|          | 0/4 [00:00<?, ?it/s]
#  Done tract LC_L_PirTB_L
#  Done tract LC_L_PirT_L
#  Done tract LC_R_PirTB_R
#  Done tract LC_R_PirT_R
#  Generated histograms in /share/ConnLS/ADNI/tract_stats/LC-MTL/figures.
# Threshold: 0.5
# Generating histograms:   0%|          | 0/4 [00:00<?, ?it/s]
#  Done tract LC_L_PirTB_L
#  Done tract LC_L_PirT_L
#  Done tract LC_R_PirTB_R
#  Done tract LC_R_PirT_R
#  Generated histograms in /share/ConnLS/ADNI/tract_stats/LC-MTL/figures.
