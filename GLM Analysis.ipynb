# %%
# %load_ext autoreload
# %autoreload 2

import json
from dwitracts.glm import DwiTractsGlm


import dwitracts.plot as dwiplot
# Out:
# /gpfs01/home/lpxjr4/.conda/envs/dwi-tracts/lib/python3.7/site-packages/nilearn/__init__.py:67: FutureWarning: Python 3.7 support is deprecated and will be removed in release 0.12 of Nilearn. Consider switching to Python 3.9 or 3.10.
#   _python_deprecation_warnings()

# %%
# GLM Analysis using DwiTractsGlm class

config_file = 'project/config_glm.json'

with open(config_file, 'r') as myfile:
    params = json.loads(myfile.read())
    
params_gen = params['general']
params_glm = params['glm']

with open(params_gen['tracts_config_file'], 'r') as myfile:
    json_string=myfile.read()
    
params['tracts'] = json.loads(json_string)

with open(params_gen['preproc_config_file'], 'r') as myfile:
    json_string=myfile.read()
    
params['preproc'] = json.loads(json_string)

my_glm = DwiTractsGlm( params )

# Initialize the object with the current parameters
assert my_glm.initialize( )
# Out:
# Creating debug directory at /share/ConnLS/ADNI/tract_stats/LC-MTL/debug
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_LC_L_LC_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_LC_L_Ent_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_LC_L_PirT_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_LC_L_PirTB_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_Ent_L_PirT_L.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_Ent_L_PirTB_L.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_Ent_L_LC_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_Ent_L_Ent_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_Ent_L_PirT_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_Ent_L_PirTB_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirT_L_PirTB_L.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirT_L_LC_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirT_L_Ent_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirT_L_PirT_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirT_L_PirTB_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirTB_L_LC_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirTB_L_Ent_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirTB_L_PirT_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirTB_L_PirTB_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_Ent_R_PirT_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_Ent_R_PirTB_R.nii.gz
# Tract not found: /share/ConnLS/ADNI/tract_stats/LC-MTL/final/tract_final_bidir_PirT_R_PirTB_R.nii.gz

# %%
# Fit all specified GLMs and save results to target directory
assert my_glm.fit_glms( clobber=True, verbose=True )
# Out:
# Computing GLMs for 6 tracts.
# Writing results to /share/ConnLS/ADNI/tract_stats/LC-MTL/glms/glm-default.
# Progress:   0%|          | 0/6 [00:00<?, ?it/s]
#    Processing LC_L_Ent_L
# Read betas:   0%|          | 0/593 [00:00<?, ?it/s]
# Missing tract data for 0 rows.
# glm-default:   0%|          | 0/1190 [00:00<?, ?it/s]
#       Writing residuals (182, 218, 182, 593)
#       Wrote glm-default-Intercept
#       Wrote glm-default-AGE
#       Wrote glm-default-FEMALE
#       Wrote glm-default-AD
#       Wrote glm-default-MCI
#    Finished LC_L_Ent_L
#    Processing LC_L_PirTB_L
# Read betas:   0%|          | 0/593 [00:00<?, ?it/s]
# Missing tract data for 0 rows.
# glm-default:   0%|          | 0/903 [00:00<?, ?it/s]
#       Writing residuals (182, 218, 182, 593)
#       Wrote glm-default-Intercept
#       Wrote glm-default-AGE
#       Wrote glm-default-FEMALE
#       Wrote glm-default-AD
#       Wrote glm-default-MCI
#    Finished LC_L_PirTB_L
#    Processing LC_L_PirT_L
# Read betas:   0%|          | 0/593 [00:00<?, ?it/s]
# Missing tract data for 0 rows.
# glm-default:   0%|          | 0/1117 [00:00<?, ?it/s]
#       Writing residuals (182, 218, 182, 593)
#       Wrote glm-default-Intercept
#       Wrote glm-default-AGE
#       Wrote glm-default-FEMALE
#       Wrote glm-default-AD
#       Wrote glm-default-MCI
#    Finished LC_L_PirT_L
#    Processing LC_R_Ent_R
# Read betas:   0%|          | 0/593 [00:00<?, ?it/s]
# Missing tract data for 0 rows.
# glm-default:   0%|          | 0/1233 [00:00<?, ?it/s]
#       Writing residuals (182, 218, 182, 593)
#       Wrote glm-default-Intercept
#       Wrote glm-default-AGE
#       Wrote glm-default-FEMALE
#       Wrote glm-default-AD
#       Wrote glm-default-MCI
#    Finished LC_R_Ent_R
#    Processing LC_R_PirTB_R
# Read betas:   0%|          | 0/593 [00:00<?, ?it/s]
# Missing tract data for 0 rows.
# glm-default:   0%|          | 0/843 [00:00<?, ?it/s]
#       Writing residuals (182, 218, 182, 593)
#       Wrote glm-default-Intercept
#       Wrote glm-default-AGE
#       Wrote glm-default-FEMALE
#       Wrote glm-default-AD
#       Wrote glm-default-MCI
#    Finished LC_R_PirTB_R
#    Processing LC_R_PirT_R
# Read betas:   0%|          | 0/593 [00:00<?, ?it/s]
# Missing tract data for 0 rows.
# glm-default:   0%|          | 0/1188 [00:00<?, ?it/s]
#       Writing residuals (182, 218, 182, 593)
#       Wrote glm-default-Intercept
#       Wrote glm-default-AGE
#       Wrote glm-default-FEMALE
#       Wrote glm-default-AD
#       Wrote glm-default-MCI
#    Finished LC_R_PirT_R
# Done.

# %%
# Extract distance traces from the GLM results
assert my_glm.extract_distance_traces( clobber=True, verbose=True )
# Out:
# Progress:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating LC_L_Ent_L
#    Done glm-default
# Evaluating LC_L_PirTB_L
#    Done glm-default
# Evaluating LC_L_PirT_L
#    Done glm-default
# Evaluating LC_R_Ent_R
#    Done glm-default
# Evaluating LC_R_PirTB_R
#    Done glm-default
# Evaluating LC_R_PirT_R
#    Done glm-default

# %%
# Extract distance traces from the GLM results, using RFT1D cluster inference
assert my_glm.extract_distance_traces_rft1d( clobber=True, verbose=True, debug=True )
# Out:
# glm-default
#  AGE
#     Mean FWHM is 3.72690
# Performing cluster inference:   0%|          | 0/6 [00:00<?, ?it/s]
# Saving results:   0%|          | 0/6 [00:00<?, ?it/s]
#  FEMALE
#     Mean FWHM is 3.72690
# Performing cluster inference:   0%|          | 0/6 [00:00<?, ?it/s]
# Saving results:   0%|          | 0/6 [00:00<?, ?it/s]
#  AD
#     Mean FWHM is 3.72690
# Performing cluster inference:   0%|          | 0/6 [00:00<?, ?it/s]
# Saving results:   0%|          | 0/6 [00:00<?, ?it/s]
#  MCI
#     Mean FWHM is 3.72690
# Performing cluster inference:   0%|          | 0/6 [00:00<?, ?it/s]
# Saving results:   0%|          | 0/6 [00:00<?, ?it/s]
#    Wrote volumes & polylines.
#    Has significant t-values [AGE]:
#    Has significant t-values [FEMALE]:
#    Has significant t-values [AD]:
#    Has significant t-values [MCI]:
#  Wrote results to /share/ConnLS/ADNI/tract_stats/LC-MTL/glms/glm-default/summary-max_thr50/tcounts-rft.csv

# %%
# Extract distance traces from the GLM results, using cluster inference and permutation testing
# my_glm.extract_distance_trace_clusters( clobber=True, verbose=True, debug=True )

# %%
# Plot t-value distance traces

# Font sizes
params['axis_font'] = 24
params['yticklabel_font'] = 16
params['xticklabel_font'] = 20
params['title_font'] = 40
params['font_scale'] = 1.5
params['image_format'] = 'svg'
params['alpha'] = 0.05
params['write_data'] = True

alpha = 0.05

tract_names = my_glm.tract_names.copy()
tract_names.sort()

# Uncorrected
params['stat_type'] = 'uncorrected'
dwiplot.plot_distance_traces( params, tract_names )

# RFT corrected
params['stat_type'] = 'rft'
dwiplot.plot_distance_traces( params, tract_names )

# Permutation corrected
# dwiplot.plot_distance_traces( params, tract_names, alpha=alpha, stat_type='perm' )

# %%
# Plot scatterplots & violin plots for GLM results

# Specify GLM
glm = 'glm-default'

# Set up parameters
params_plot = {}
params_plot['glm'] = glm
params_plot['alpha'] = 0.05
params_plot['outlier_z'] = params_glm[glm]['outlier_z']
params_plot['stat_type'] = 'rft'
params_plot['axis_font'] = 40
params_plot['marker_size'] = 15
params_plot['line_width'] = 4
params_plot['ticklabel_font'] = 33
params_plot['title_font'] = 45
params_plot['legend_font'] = 40
params_plot['legend_scale'] = 3
params_plot['show_title'] = True
params_plot['show_legend'] = True
params_plot['dimensions'] = (12,10)
params_plot['font_scale'] = 0.6
params_plot['write_csv'] = False
params_plot['image_format'] = 'svg'
params_plot['write_data'] = True

# Loop through tracts and call plot function for each
dwiplot.plot_glm_results_all( params_plot, my_glm, verbose=True )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1069423/547814386.py in <module>
#       8 params_plot['glm'] = glm
#       9 params_plot['alpha'] = 0.05
# ---> 10 params_plot['outlier_z'] = params_glm[glm]['outlier_z']
#      11 params_plot['stat_type'] = 'rft'
#      12 params_plot['axis_font'] = 40
#
# KeyError: 'glm-age-sex'

# %%
# Aggregate tracts into single volumes
assert my_glm.aggregate_tracts(prefix='tract_final_norm_bidir', op='max', verbose=True)

# %%
# Aggregate tracts crossing corpus callosum
cc_img = '/Volumes/GDriveUsb/data/atlases/corpus_callosum_midline.nii'
assert my_glm.aggregate_tracts(prefix='tract_final_norm_bidir', suffix='_cc', intersects=cc_img, \
                                op='max', threshold=0, verbose=True)

# %%
# Aggregate stats into single volumes

assert my_glm.aggregate_stats( op='max', pthres=0.05, suffix='-rft', verbose=True, clobber=True )

# %%
# Generate Pajek graphs

assert my_glm.create_pajek_graphs( suffix='-rft', edge_val='tsum', verbose=True, clobber=True )
